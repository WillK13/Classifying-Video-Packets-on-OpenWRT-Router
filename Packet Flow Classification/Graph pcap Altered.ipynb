# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
wd = pd.read_csv('final_packet_test_1.csv', delimiter = ',', encoding='latin-1', header=0)
wd.sample(10)
# Out:
#          No.         Time          Source    Destination Protocol  Length  \
# 48300  48301   995.610564   192.168.8.219    74.125.0.56      TCP      66
# 77137  77138  1271.732425  173.194.31.120  192.168.8.219      TCP    1470
# 13655  13656   428.928908   172.217.129.8  192.168.8.219      TCP    1470
# 32586  32587   770.967625   192.168.8.219    74.125.0.56      TCP      66
# 71920  71921  1251.564298  173.194.31.120  192.168.8.219      TCP    1470
# 43708  43709   919.672792   192.168.8.219    74.125.0.56      TCP      66
# 49404  49405   995.857323   192.168.8.219    74.125.0.56      TCP      66
# 55110  55111  1176.704347     74.125.0.11  192.168.8.219      TCP    1470
# 80452  80453  1285.873160  173.194.31.120  192.168.8.219      TCP    1470
# 175      176     6.869426   172.217.129.8  192.168.8.219      TCP    1470
#
#       Transmission Control Protocol      Frame   Ethernet  \
# 48300                     â\234\223  â\234\223  â\234\223
# ...

# %%
plt.rcParams["figure.figsize"] = (20,10)
plt.plot(wd['Time'], wd['Protocol'], 'o', color='DarkGreen')
plt.title('Protocol Vs. Time')
plt.xlabel('Time')
plt.ylabel('Protocol')
plt.show()
plt.plot(wd['Time'], wd['Source'], 'o', color='DarkBlue')
plt.title('Source IP Vs. Time')
plt.xlabel('Time')
plt.ylabel('Source')
plt.show()

# %%
plt.rcParams["figure.figsize"] = (25,10)
plt.plot(wd['Source'].str[-5:], wd['Protocol'].str[-5:], 'o',)
plt.title('More detailed without time')
plt.xlabel('Source')
plt.ylabel('Protocol')
plt.show()

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans

# %%
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.rcParams["figure.figsize"] = (25,10)
plt.plot(wd['Source'].str[-5:], wd['Protocol'].str[-5:], 'o',)
plt.title('More detailed without time')
plt.xlabel('Source')
plt.ylabel('Protocol')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-7a6de41c6e93> in <module>
#       2 for i in range(1, 11):
#       3     kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
# ----> 4     kmeans.fit('Time')
#       5     wcss.append(kmeans.inertia_)
#       6 plt.rcParams["figure.figsize"] = (25,10)
#
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py in fit(self, X, y, sample_weight)
#    1028             Fitted estimator.
#    1029         """
# -> 1030         X = self._validate_data(X, accept_sparse='csr',
#    1031                                 dtype=[np.float64, np.float32],
#    1032                                 order='C', copy=self.copy_x,
#
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
# ...
